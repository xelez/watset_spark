# %%
from __future__ import print_function

# %%
# возвращает True если в графе для каждого ребра u->v есть соответствующее ребро v->u
def check_graph_is_ordered(inp):
    all_edges = {}
    for u,v,_ in inp:
        all_edges[(u,v)] = True
    
    for u,v,_ in inp:
        if not all_edges.get( (v,u), False):
            return False
        
    return True

# %% [markdown]
# # Read graph, convert words to ids

# %%
lines = open('watset/data/ru/edges.count.txt').read().strip().split('\n')
inp = map(lambda t : t.split('\t'), lines)
print(len(inp))
# Out:
# 425420

# %%
check_graph_is_ordered(inp)
# Out:
# True

# %%
_words2id = {}
_id2words = {}
_N = 0

def word2id(word):
    global _N
    i = _words2id.get(word)
    if i is None:
        _words2id[word] = _N
        _id2words[_N] = word
        i = _N
        _N += 1
    return i

def id2word(i):
    return _id2words[i]

# %%
from collections import defaultdict
reb = defaultdict(list)

for u, v, w in inp:
    u, v, w = word2id(u), word2id(v), int(w)
    reb[u].append( (v, w) )

# %% [markdown]
# # get EGO graphs and clusterize them

# %%
def make_ego(u):
    V = set(map(lambda x: x[0], reb[u]))
    ego_reb = {}
    for v in V:
        ego_reb[v] = filter(lambda edge: edge[0] in V, reb[v])
        
    return ego_reb

# %%
def argmax(items, default_value = 0.0):
    best_arg, best_value = None, default_value
    for arg, value in items:
        if value > best_value:
            best_arg, best_value = arg, value
    return best_arg

# %%
import random

def chinise_whispers(reb, max_steps = 10):
    V = reb.keys()
    classes = { u : i for i, u in enumerate(V) }
    for i in range(max_steps):
        random.shuffle(V)
        for u in V:
            cnt = defaultdict(float)
            for v, w in reb[u]:
                cnt[classes[v]] += w # TODO: change this for other measures
            
            classes[u] = argmax(cnt.items(), default_value=-1.0)

    clusters = defaultdict(list)
    for u, cls in classes.items():
        clusters[cls].append(u)
        
    return clusters.values()

# %%
senses = {}
ctx = {}

for u in reb.keys():
    ego_reb = make_ego(u)
    weights = dict(reb[u])
    #print(id2word(u), ego_reb)
    clusters = chinise_whispers(ego_reb)
    
    senses[u] = []
    for i, cluster in enumerate(clusters):
        s = u*1000 + i
        senses[u].append(s)
        ctx[s] = {v : weights[v] for v in cluster}

# %%
len(reb), len(senses), len(ctx)
# Out:
# (83588, 83588, 111458)

# %%
import math

# ctx1, ctx2 can be basically
# a) dict with fast lookup by key on ctx1 and ctx2
# b) list of pairs, sorted by keys
# this function is for dicts
def cos_sim(ctx1, ctx2):
    dot_product = 0
    
    sum1 = 0
    sum2 = 0
    
    for u, weight in ctx1.items():
        dot_product += weight * ctx2.get(u, 0)
        sum1 += weight**2
        
    for _, weight in ctx2.items():
        sum2 += weight**2
        
    return dot_product / math.sqrt(sum1 * sum2)

# %%
# depends on senses[], ctx[]
def disambiguate_word(v, context):
    similarities = [sense_v, cos_sim(context, ctx[sense_v]) for sense_v in senses[v]]
    return argmax(similarities)

# %%
ctx_new = {}

for s, curr_ctx in ctx.items():
    context = dict(curr_ctx)
    context[s // 1000] = 1 # hack to add current word to context as in disambiguate.py
    
    ctx_new[s] = { disambiguate_word(v, context) : weight for v, weight in curr_ctx.items() }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-37883e0ddf6b> in <module>()
#       1 ctx_new = {}
#       2
# ----> 3 for s, curr_ctx in ctx.items():
#       4     context = dict(curr_ctx)
#       5     context[s // 1000] = 1 # hack to add current word to context as in disambiguate.py
#
# NameError: name 'ctx' is not defined

# %%
len(ctx_new.items()), len(reb), len(senses), len(ctx)
# Out:
# 111458

# %%
for x in ctx_new.keys():
    ctx_new[x] = ctx_new[x].items()

# %%
clusters = chinise_whispers(ctx_new)

# %% [markdown]
# # Result output

# %%
def cluster2str(cluster):
    return '{0}\t{1}'.format(len(cluster), ', '.join( id2word(v // 1000) + str(v% 1000) for v in cluster) )

# %%
clusters.sort(key=len, reverse=True)

# %%
for c in clusters[50:60]:
    print(cluster2str(c))
# Out:
# 70	вдовень0, ни_душой_ни_телом0, водерень0, на_хуй0, до_корня0, на_три_буквы0, вдокон0, в_конец0, вдрызг0, абсолютно0, цельно0, куда_подальше0, всесторонне1, совсем0, далеко_и_надолго0, ровно2, в_сторонку0, напрочь0, отнюдь1, в_пизду2, к_чёрту0, к_чёрту1, на_хуй1, радикально1, всюду1, сполна0, напротив3, начисто1, во_всем_объеме0, ни_сном_ни_духом0, на_хрен0, с_какой_целью2, насовсем1, полно2, решительно0, решительно3, полноценно0, вконец0, в_лоск0, все6, вдосталь1, вовсе1, всесторонне0, коренным_образом1, кругом0, многосторонне0, с_головы_до_пят1, целиком0, к_дьяволу0, твердо0, радикально0, вконец1, бесповоротно0, наголову0, полностью0, от_начала_до_конца0, диаметрально0, разносторонне0, ко_всем_чертям0, на_хер0, вполне0, окончательно1, ни_сном_ни_духом1, в_корень0, далеко_и_без_куска_хлеба0, совершенно3, ровным_счётом0, всецело0, в_пизду1, кардинально0
# 69	убеждённость1, прозорливость0, взгляд1, воззрение1, коллегия2, догадка3, мировоззрение0, мировоззрение1, усмотрение0, синедрион2, проницательность0, заключение0, министерство0, исходное_положение0, основополагающее_правило0, мнение0, менталитет0, выведение0, благоусмотрение0, воззрения0, воображение0, домысел1, пленение0, находчивость2, подтекст1, отчет0, образ_мышления0, убеждение0, принципы0, кодекс1, сметливость2, различение0, философия1, мысль2, вывод0, суждение1, суждение2, миропонимание0, принцип0, принцип1, рассуждение1, точка_зрения1, заключение6, взгляды0, ментальность0, образ_мыслей0, образ_мыслей2, мораль2, умозаключение1, глазомер0, термин3, намерение2, характер1, коллегия0, понимание2, уверение0, предположение2, силлогизм0, глас1, правила0, соображение1, устав1, убеждение3, миросозерцание0, профсоюз0, заверение0, понятье0, идеология0, понятие0
# 69	требовательный1, крепкотелый0, крупный1, поддатый1, несказанный1, мягкий6, авторитетный1, веский0, властный3, влиятельный0, всевластный0, действующий_внушительный0, дюжий1, крепкий1, неиспорченный1, всемогущий0, могучий2, могущий0, могущественный0, неутомимый5, мощный2, плотный4, повелительный1, престижный2, действующий1, {{?|крепкий0, туз5, накачанный0, уважительный1, всесильный0, державный0, здоровый0, хороший0, здоровенный1, крутой4, крутой5, нарочитый1, резкий2, резкий4, значительный0, термоядерный0, мощный0, матерый1, ядрёный0, впечатляющий1, водородный0, свежий3, здоровый6, чрезвычайный0, профузный0, глубокий4, атлетичный0, бодрый5, мускулистый0, мускулистый1, важный2, отличный3, внушительный3, сильный0, способный5, внезапный1, неожиданный1, здравый0, велемощный0, сочный1, обильный6, цветущий0, жилистый0, выздоровевший0
# 68	малец1, грузный0, корпулентный0, ожирелый0, ожирелый1, толстяк0, тучненький0, тяжелый2, дородный0, сбитый0, круглый1, облый2, округлый1, плотный5, барабан0, утробистый1, корпулентный1, пузатый2, закруглённый0, кругловатый0, бочка0, укомплектованный0, полненький0, пухленький0, комплексный0, безнадежный2, плотный0, сытный0, полномерный0, о-образный0, тушистый0, выпуклый1, стопроцентный1, гладкий3, тимпан0, размеренный1, жиртрест1, ботелый0, жирненький0, жирненький1, толстенький0, пухлый1, пухлый2, светонепроницаемый0, толстый0, комплектный1, баррель0, жиропупокомбинат0, толстобрюхий0, толстомясый0, полнёхонький0, тучный0, широкий1, жирдяй1, гладыш0, облый0, дебелый0, полнёшенький0, ожиревший0, упитанный0, полный1, жирный1, обильный3, комплектный0, бочка3, бутуз0, откормленный0, округлый0
# 67	роскошный2, неподвижный0, мешкотный0, онемелый0, покоящийся0, бездеятельный0, каменный0, косный0, косный1, безжизненный1, безжизненный2, сонливый0, твёрдый1, нерасчётливый0, сонный1, пассивный0, бессимптомный0, брадипсихический0, застывший0, ленивый0, халатный1, блаженный2, торпидный0, недвижимый0, неповоротливый1, оцепенелый1, заторможенный0, воздержанный1, задумчивый2, окаменелый1, томный0, бесхозяйственный0, апатичный0, флегматический0, разбитной1, оцепенелый0, нераздражительный0, вялый4, равнодушный3, флегматичный0, рахманный0, бесстрастный0, благоденствующий0, бесчувственный3, дряблый2, торпидный1, инертный2, мешкотный_неповоротливый0, безынициативный0, окаменелый0, медлительный0, неподвижный3, разгульный1, нерасторопный1, слабосильный1, весёлый2, похороненный1, тяжелый_на_подъем0, базальтовый0, медлительный1, ригидный0, окаменевший0, простодушный2, медлительный_неповоротливый0, рахманный3, омертвелый0, малосимптомный0
# 67	попсня0, кардинал1, основоположник1, ксендз0, па1, отец_семейства0, настоятель0, патер0, пономарь1, Папа_Римский0, диак.0, патриарх0, псаломщик0, протоиерей1, игумен0, пономарь0, священник1, князь_церкви0, чтец1, отец_церкви0, падре0, тя0, прелат0, экзарх0, митрополит0, дьякон0, суперинтендент0, пресвитер0, свещеносец0, поп0, викарий0, диакон1, духовенство4, служитель_алтаря0, кардинал0, католикос0, митрополит1, пастор0, свечегас0, привидение4, архимандрит0, стихарь0, батюшка1, протоиерей0, протопресвитер0, протопоп0, архипастырь0, владыка3, иерарх2, архиерей0, монах1, аббат0, архимандрит1, пробст0, архиепископ0, папа0, папенька1, отец0, подмарь0, кардиналовая_овсянка0, старейшина1, протодиакон0, пастырь0, епископ0, проповедник2, иерей0, диакон0
# 66	сминать3, превзойти1, сломить0, покорять3, сразить1, ошарашивать0, возобладать1, обезоружить2, сладить1, превзойти0, справиться1, побить_рекорд0, побарывать0, заткнуть_за_пояс0, одерживать_верх0, обогнать0, затмить0, оставить_за_флагом0, пожинать_лавры0, перегнать0, поборать0, преодолевать2, сломить1, выиграть_сражение1, преодолевать0, выигрывать3, обойти4, обыгрывать0, опередить0, громить1, торпедировать0, получить_пальму_первенства0, огорошивать1, побеждать0, отменять2, сломать0, погубить2, взять_верх1, взять_перевес1, восторжествовать2, одержать_победу1, одолевать2, осиливать1, потрясти0, перещеголять2, впечатлять0, смирять1, совладать2, справляться5, обскакать0, оставить_позади0, побороть1, поражать0, поражать6, побивать1, разить1, впечатлить0, побарывать1, поломать0, потрясти1, превозмогать1, превосходить1, превышать0, легко_справляться0, поразить1, разбить2
# 66	чуждый1, презрительный3, незлобный0, ангельский4, безжелчный0, схимник2, беззлобный0, безличный0, безличный1, безобидный0, безобидный1, безответный0, безответный1, безропотный0, смиренный0, добродушный2, добросердечный4, кроткий0, миролюбивый3, молчаливый1, мухи_не_обидит0, мягкий3, незлобивый3, праведный2, скромный3, смирный3, снисходительный3, терпеливый1, тихий1, тишайший0, уступчивый0, собирательный0, тише_воды_ниже_травы0, немногословный1, правосудный0, смиренник1, покорный3, неточный1, неразделённый0, шелковый1, мирный0, простецкий0, несловоохотливый0, водой_не_замутит0, покорный_судьбе0, неоплаченный0, снисходительный0, нереферентный0, нестрогий0, великодушный1, обобщённый0, неиндивидуализированный0, либеральный0, потакающий0, безгневный0, простой10, елейный0, незлобивый0, неразговорчивый2, рахманный1, невинный1, необидный0, имперсональный0, неподелённый0, отходчивый1, неразговорчивый0
# 66	распоясавшийся0, мятежный3, разнузданный0, неуёмный0, безудержный0, бредовый0, бредовый1, необузданный1, неукротимый1, бешеный3, блажной0, взбалмошный1, разнузданный2, веселый0, шалый0, горячечный0, яростный2, безумный3, исступленный0, шальной1, оголтелый1, кипящий0, исступлённый0, невоздержный2, бунтливый0, взбесившийся0, неумеренный1, остервенелый1, бесстыдный1, игристый0, сумасшедший0, неистовый0, деятельный2, кипучий0, кипучий2, бурлящий0, страстный2, ярый3, оживлённый1, сумасбродный0, отчаянный2, неудержимый0, неудержимый1, неумеренный0, отъявленный2, темпераментный1, безрассудный0, беспредельный2, пенящийся0, шипучий0, переливающийся_через_край0, безбашенный1, фанатичный0, мятущийся0, обезбашенный0, невоздержный0, мятежный0, оголтелый0, невоздержанный0, бесшабашный1, дикий2, оголченный0, буйный0, бешеный0, ярый0, сатанинский0
# 65	непонятливость0, сглупа0, безумность0, влекомость0, по_глупости0, незамысловатость0, безрассудность0, одержимость2, помешательство1, одержимость0, идиотия0, глупость2, глупость3, имбецилизм0, {{aslinks|простодушие0, сделать_глупость1, безумие0, пассионарность0, дебилизм0, безумие2, имбецильность0, лихоманка0, неискушённость0, дебильность0, затуплённость0, полушалок0, горячка3, раж2, частичн._имбецильность0, скудоумие0, сумасшествие0, беспорядок1, мания0, азбучность0, тупость0, тупость1, идиотство0, простота0, простота2, лихорадка0, безумье0, полоумие0, дурь0, идиотизм0, недомыслие0, дебилизм1, имбецильность1, безрассудство0, тупоумие0, полоумие1, наивность1, неистовство2, мишигас0, безумие3, бессмыслие0, блажь2, ребячество3, простосердечие1, душевная_болезнь0, слабоумие0, безумство0, сумасбродство0, шаль0, шаль3, неразумие0
